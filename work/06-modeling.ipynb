# %%
import pandas as pd
import numpy as np

# %% [markdown]
# First, we will try simply classifying the data. The goal here is to create a model that accurately determines the category of product a user will purchase. However, this strips our data of the sequential patterns that may be present in the data by treating each row as a single purchase, rather than as part of a sequence of purchases. Future models will aim to uncover such patterns.

# %%
from sklearn.preprocessing import StandardScaler

data = pd.read_csv('/workspaces/group-project-bas-team/data/cleaned_data.csv')

train = data[data['order_year']<=2021]
test = data[data['order_year']>2021]

data_limited_train = train.drop(['Title', 'ASIN/ISBN (Product Code)'], axis=1)
data_limited_test = test.drop(['Title', 'ASIN/ISBN (Product Code)'], axis=1)

X_train = data_limited_train.drop('Category', axis=1)
y_train = data_limited_train['Category']
X_train_scaled = StandardScaler().fit_transform(X_train)

X_test = data_limited_test.drop('Category', axis=1)
y_test = data_limited_test['Category']
X_test_scaled = StandardScaler().fit_transform(X_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=93)
X_train_reduced = pca.fit_transform(X_train_scaled)
X_test_reduced = pca.fit_transform(X_test_scaled)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

knn = KNeighborsClassifier()
knn.fit(X_train_reduced, y_train)
pred = knn.predict(X_test_reduced)

accuracy_score(y_test, pred)
# Out:
# 0.015010029743376911

# %%
knn = KNeighborsClassifier()
knn.fit(X_train_scaled, y_train)
pred = knn.predict(X_test_scaled)

accuracy_score(y_test, pred)
# Out:
# 0.033847501786908304

# %%
# Decision tree regressor
# Taking a while to run - i assume because our dataset is still very large
# May come back to this later

# from sklearn.ensemble import RandomForestClassifier

# forest = RandomForestClassifier()
# forest.fit(X_train_reduced, y_train)

# pred = forest.predict(X_test_reduced)
# accuracy_score(y_test, pred)
